# %%
import pandas as pd
import matplotlib.pyplot as plt
filename='C:/Users/STUDENT/Desktop/shiva 165/matches.csv'
df=pd.read_csv(filename)
data=pd.DataFrame(df)
#print(data)
#print(data.sort_values(by='win_by_runs'))
#print(data.sort_values(by='season'))
s=pd.Series(data['winner'].value_counts())
labels=['Mumbai Indians','Chennai Super Kings','Kolkata Knight Riders','Royal Challengers Bangalore','Kings XI Punjab','Rajasthan Royals',
       'Delhi Daredevils','Sunrisers Hyderabad','Deccan Chargers','Gujarat Lions','Pune Warriors','Rising Pune Supergiant','Kochi Tuskers Kerala',
       'Rising Pune Supergiants']
plt.figure(figsize=(5,5))
plt.pie(s, labels=labels)
plt.show()
